# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("customer_churn_cleaned.csv")
df.head()
# Out:
#    Age  Gender  Tenure  MonthlyCharges        Contract     PaymentMethod  \
# 0   56  Female      68          147.58        Two year     Bank transfer
# 1   69    Male      32           22.54  Month-to-month      Mailed check
# 2   46  Female      10           52.47        One year  Electronic check
# 3   32    Male      22          109.67  Month-to-month      Mailed check
# 4   60  Female      54          130.98  Month-to-month       Credit card
#
#    TotalCharges Churn
# 0      10052.03    No
# 1        686.78    No
# 2        537.88    No
# 3       2390.04   Yes
# 4       7081.28    No

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df,x='Churn')
plt.title('customer churn distribution')
plt.show()

# %%
(df['Churn'].value_counts(normalize=True)*100).round(2)
# Out:
# Churn
# No     66.93
# Yes    33.07
# Name: proportion, dtype: float64

# %%
pd.crosstab(df["Gender"],df['Churn'])
# Out:
# Churn      No    Yes
# Gender
# Female  32352  15776
# Male    31783  15879
# Other    2616   1329

# %%
(pd.crosstab(df['Gender'],df['Churn'],normalize='index')*100).round(2)
# Out:
# Churn      No    Yes
# Gender
# Female  67.22  32.78
# Male    66.68  33.32
# Other   66.31  33.69

# %%
plt.figure(figsize=(8,6))

sns.countplot(data=df,x='Gender',hue='Churn')
plt.title('Gender vs Churn')
plt.show()

# %%
pd.crosstab(df['Contract'],df['Churn'])
# Out:
# Churn              No    Yes
# Contract
# Month-to-month  29314  25461
# One year        20988   4205
# Two year        16449   3318

# %%
(pd.crosstab(df['Contract'],df["Churn"],normalize='index')*100).round(2)
# Out:
# Churn              No    Yes
# Contract
# Month-to-month  53.52  46.48
# One year        83.31  16.69
# Two year        83.21  16.79

# %%
plt.figure(figsize=(8,6))

sns.countplot(data=df,x='Contract',hue='Churn')
plt.title('Contract vs Churn')
plt.show()

# %%
pd.crosstab(df['PaymentMethod'],df['Churn'])
# Out:
# Churn                No    Yes
# PaymentMethod
# Bank transfer     13287   6515
# Credit card       13447   6532
# Electronic check  23239  11566
# Mailed check      16778   8371

# %%
(pd.crosstab(df['PaymentMethod'],df["Churn"],normalize='index')*100).round(2)
# Out:
# Churn                No    Yes
# PaymentMethod
# Bank transfer     67.10  32.90
# Credit card       67.31  32.69
# Electronic check  66.77  33.23
# Mailed check      66.71  33.29

# %%
plt.figure(figsize=(8,6))

sns.countplot(data=df,x='PaymentMethod',hue='Churn')
plt.title('PaymentMethod vs Churn')
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.boxplot(data=df, x='Churn',y='Age')
plt.title('Churn vs Age')
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.boxplot(data=df,x='Churn',y="Tenure")
plt.title("Churn vs Tenure")
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.boxplot(data=df, x='Churn',y='MonthlyCharges')
plt.title('Churn vs MonthlyCharges')
plt.show()

# %%
sns.boxplot(data=df,x='Churn',y='TotalCharges')
plt.title('Churn vs TotalCharges')
plt.show()
